# %%
import numpy as np
import matplotlib.pyplot as plt
import math
#import bokeh.io
from bokeh.plotting import figure, show
#import bokeh.models

# %%
# importing the modules
from bokeh.plotting import figure, output_file, show

# file to save the model
output_file("gfg.html")

# instantiating the figure object
graph = figure(title = "Bokeh Line Graph")

# the points to be plotted
x = [1, 2, 3, 4, 5]
y = [1, 6, 8, 2, 3]

# plotting the line graph
graph.line(x, y)

# displaying the model
show(graph)

# %%
current_1 = [
    0.008762626263,
    0.008121212121,
    0.007474747475,
    0.006904040404,
    0.006424242424,
    0.005909090909,
    0.00546969697,
    0.005025252525,
    0.004595959596,
    0.004191919192,
    0.003801515152,
    0.003393939394,
    0.003050505051,
    0.002717171717,
    0.002343434343,
    0.001994949495,
    0.001681818182,
    0.001358585859,
    0.001075757576,
    0.0005252525253,
    0.0002878787879,
    0.00008080808081,
    -0.00005050505051,
    -0.0001464646465,
    -0.0001464646465,
    -0.0001464646465,
    -0.000005050505051,
    -0.000005050505051,
    -0.000005050505051,
    -0.000005050505051,
    -0.000005050505051
]

current_1 = np.array(current_1)
voltage_1 = [
    7.235,
    6.892,
    6.74,
    6.575,
    6.383,
    6.165,
    5.967,
    5.768,
    5.522,
    5.295,
    5.1103,
    4.89,
    4.654,
    4.439,
    4.196,
    3.975,
    3.749,
    3.501,
    3.267,
    2.856,
    2.613,
    2.374,
    2.083,
    1.529,
    1.217,
    0.919,
    0.32,
    0.014,
    0.0297,
    -0.594,
    -0.875
]

voltage_1 = np.array(voltage_1)

# %%
current = [
    0.01187373737, 0.01136363636, 0.01075757576, 0.0101010101, 0.009494949495,
    0.008888888889, 0.008232323232, 0.007626262626, 0.00702020202, 0.006414141414,
    0.005808080808, 0.005202020202, 0.004595959596, 0.003383838384, 0.002828282828,
    0.002272727273, 0.001666666667, 0.001111111111, 0.0002727272727, 0.000101010101,
    -0.000101010101, -0.000101010101, -0.000101010101, -0.000101010101, -0.000101010101,
    -0.000101010101, -0.000101010101, -0.000101010101, -0.000101010101
]

current = np.array(current)
voltage = [
    2.146, 2.12, 2.1, 2.08, 2.06, 2.07, 2.07, 2.06, 2.04, 2.02, 2.0, 1.97, 1.96,
    1.94, 1.9, 1.89, 1.89, 1.85, 1.746, 1.63, 1.52, 1.27, 1.15, 1.01, 0.746, 0.618,
    0.473, 0.335, 0.214
]

voltage = np.array(voltage)

# %%
plt.figure(figsize=(5,4))
plt.rc('font', size=10)
plt.plot(voltage_1, current_1, color='orange')
plt.plot(voltage, current, color='red')
plt.xlabel('Voltage of Yellow and Red LED (V)', fontsize=10)
plt.ylabel('Current',fontsize=10)
# Out:
# Text(0, 0.5, 'Current')

# %%
p = figure(width=400, height=400)

# add a line renderer
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)

show(p)

# %%
plt.figure(figsize=(5,4))
plt.rc('font', size=10)
plt.plot(freq, gain, 'o-', color='purple', label='blue')
plt.xlim(0.45)
plt.xlabel('Frequency (kHz)', fontsize=10)
plt.ylabel('Gain',fontsize=10)
plt.axvline(300, linestyle='--')
plt.grid()
plt.xscale('log')
plt.yscale('log')

# %%
plt.figure(figsize=(5,4))
plt.rc('font', size=10)
plt.plot(freq, dB, 'o-', color='purple', label='blue')
plt.xlim(0.45)
plt.xlabel('Frequency (kHz)', fontsize=10)
plt.ylabel('Voltage Level L (dB)',fontsize=10)
plt.axvline(300, linestyle='--')
plt.grid()
plt.xscale('log')
plt.yscale('log')

# %%
plt.figure(figsize=(5,4))
plt.rc('font', size=10)
plt.plot(freq, dB, color='purple', label='blue')
plt.xlim(0.45)
plt.xlabel('Frequency (kHz)', fontsize=10)
plt.ylabel('Voltage Level L (dB)',fontsize=10)
plt.axvline(450, linestyle='--')
plt.grid()
plt.xscale('log')
plt.yscale('log')
